# %% [markdown]
# # Assignment 4 - Visualization
#
#
# ## Deadline: 04/17/2022 11:59PM EST
#
# - Total: 7.5
# - Code: 6.5
#     - Task 1: 2
#     - Task 2: 4.5
# - Comments/Documentation: .5
#
#
# **Note:** Interactive graphs will not render on github. This is fine...
#
# Late policy:
# - 20% off after deadline
# - Additional 10% off final grade each day after submission
#
# Plagiarism policy: see syllabus

# %% [markdown]
# ## Plotting Titanic Dataset

# %%
import pandas as pd
import numpy as np

# %%
titanic = pd.read_excel("../data/titanic.xls", "titanic")
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# # Task 1:
#
# With Matplotlib:
#
# 1. Create a bar chart for **number** of passengers that survived by class
# 2. Plot a histogram of fares paid for passengers.
#     - Use 30 bins
#
# 3. Repeat steps 1. and 2. with Plotly

# %% [markdown]
# # Task 2:
#
# With Plotly, you will display maps of demographic information on the county level.
#
# 1. Create a Choropleth map and show the total population on the county level.
#     - Set an appriorate values for range_color (use your distrection as to what makes sense)
# 2. Repeat 1. but for Total Men
# 3. Repeat 1. but for Total Women
#
#
# **Note:** A few states may not display which is fine.

# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

# %%
df = pd.read_csv("../data/acs2015_county_data.csv")
df
# Out:
#        FIPS        State     County  TotalPop    Men  Women  Hispanic  White  \
# 0      1001      Alabama    Autauga     55221  26745  28476       2.6   75.8
# 1      1003      Alabama    Baldwin    195121  95314  99807       4.5   83.1
# 2      1005      Alabama    Barbour     26932  14497  12435       4.6   46.2
# 3      1007      Alabama       Bibb     22604  12073  10531       2.2   74.5
# 4      1009      Alabama     Blount     57710  28512  29198       8.6   87.9
# ...     ...          ...        ...       ...    ...    ...       ...    ...
# 3215  72145  Puerto Rico  Vega Baja     56858  27379  29479      96.4    3.4
# 3216  72147  Puerto Rico    Vieques      9130   4585   4545      96.7    2.9
# 3217  72149  Puerto Rico   Villalba     24685  12086  12599      99.7    0.0
# 3218  72151  Puerto Rico    Yabucoa     36279  17648  18631      99.8    0.2
# 3219  72153  Puerto Rico      Yauco     39474  19047  20427      99.5    0.5
#
#       Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0      18.5     0.4  ...   0.5          1.3         1.8         26.5
# 1       9.5     0.6  ...   1.0          1.4         3.9         26.4
# 2      46.7     0.2  ...   1.8          1.5         1.6         24.1
# 3      21.4     0.4  ...   0.6          1.5         0.7         28.8
# 4       1.5     0.3  ...   0.9          0.4         2.3         34.9
# ...     ...     ...  ...   ...          ...         ...          ...
# 3215    0.1     0.0  ...   1.2          1.3         0.3         32.0
# 3216    0.0     0.0  ...  10.8          0.0         1.4         14.0
# 3217    0.0     0.0  ...   3.2          0.0         3.3         26.9
# 3218    0.0     0.0  ...   2.3          2.3         1.5         29.5
# 3219    0.0     0.0  ...   1.6          0.7         3.1         24.6
#
#       Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  \
# 0        23986         73.6        20.9           5.5         0.0
# 1        85953         81.5        12.3           5.8         0.4
# 2         8597         71.8        20.8           7.3         0.1
# 3         8294         76.8        16.1           6.7         0.4
# 4        22189         82.0        13.5           4.2         0.4
# ...        ...          ...         ...           ...         ...
# 3215     13660         78.3        17.6           4.1         0.0
# 3216      2860         44.5        41.6          13.6         0.3
# 3217      6795         59.2        27.5          13.1         0.2
# 3218      8083         65.1        27.6           7.3         0.0
# 3219      8923         68.0        27.6           4.4         0.0
#
#       Unemployment
# 0              7.6
# 1              7.5
# 2             17.6
# 3              8.3
# 4              7.7
# ...            ...
# 3215          15.2
# 3216          12.2
# 3217          25.9
# 3218          24.3
# 3219          27.1
#
# [3220 rows x 37 columns]
